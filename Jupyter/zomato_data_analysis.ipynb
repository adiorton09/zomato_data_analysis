# %% [markdown]
# # Import the data source file

# %%
import pandas as pd
df1= pd.read_csv("zomato.csv")

# %% [markdown]
# # Dropping the unnecessary columns.

# %%
df2=df1.drop(columns=['url','phone','rest_type','dish_liked','reviews_list','menu_item','listed_in(city)'] , axis=1)

# %% [markdown]
# # Renaming certain columns for easier reading

# %%
df3=df2.rename(columns={'approx_cost(for two people)':'two_people_cost','listed_in(type)':'type_of_restaurant'})

# %%
df3
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51712         No  3.6 /5     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                                      cuisines two_people_cost  \
# 0              North Indian, Mughlai, Chinese             800
# 1                 Chinese, North Indian, Thai             800
# 2                      Cafe, Mexican, Italian             800
# 3                  South Indian, North Indian             300
# 4                    North Indian, Rajasthani             600
# ...                                       ...             ...
# 51712                             Continental           1,500
# 51713                             Finger Food             600
# 51714                             Finger Food           2,000
# 51715                             Finger Food           2,500
# 51716  Finger Food, North Indian, Continental           1,500
#
#       type_of_restaurant
# 0                 Buffet
# 1                 Buffet
# 2                 Buffet
# 3                 Buffet
# 4                 Buffet
# ...                  ...
# 51712      Pubs and bars
# 51713      Pubs and bars
# 51714      Pubs and bars
# 51715      Pubs and bars
# 51716      Pubs and bars
#
# [51717 rows x 10 columns]

# %% [markdown]
# # Renaming rate to rating

# %%
df4=df3.rename(columns={'rate':'rating'})

# %%
df4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rating  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51712         No  3.6 /5     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                                      cuisines two_people_cost  \
# 0              North Indian, Mughlai, Chinese             800
# 1                 Chinese, North Indian, Thai             800
# 2                      Cafe, Mexican, Italian             800
# 3                  South Indian, North Indian             300
# 4                    North Indian, Rajasthani             600
# ...                                       ...             ...
# 51712                             Continental           1,500
# 51713                             Finger Food             600
# 51714                             Finger Food           2,000
# 51715                             Finger Food           2,500
# 51716  Finger Food, North Indian, Continental           1,500
#
#       type_of_restaurant
# 0                 Buffet
# 1                 Buffet
# 2                 Buffet
# 3                 Buffet
# 4                 Buffet
# ...                  ...
# 51712      Pubs and bars
# 51713      Pubs and bars
# 51714      Pubs and bars
# 51715      Pubs and bars
# 51716      Pubs and bars
#
# [51717 rows x 10 columns]

# %% [markdown]
# # Dropping null value rows on the basis of location , cuisines, two_people_cost

# %%
df4=df4.dropna(subset=['location'])
df4=df4.dropna(subset=['cuisines','two_people_cost'])

# %%
df4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rating  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51712         No  3.6 /5     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                                      cuisines two_people_cost  \
# 0              North Indian, Mughlai, Chinese             800
# 1                 Chinese, North Indian, Thai             800
# 2                      Cafe, Mexican, Italian             800
# 3                  South Indian, North Indian             300
# 4                    North Indian, Rajasthani             600
# ...                                       ...             ...
# 51712                             Continental           1,500
# 51713                             Finger Food             600
# 51714                             Finger Food           2,000
# 51715                             Finger Food           2,500
# 51716  Finger Food, North Indian, Continental           1,500
#
#       type_of_restaurant
# 0                 Buffet
# 1                 Buffet
# 2                 Buffet
# 3                 Buffet
# 4                 Buffet
# ...                  ...
# 51712      Pubs and bars
# 51713      Pubs and bars
# 51714      Pubs and bars
# 51715      Pubs and bars
# 51716      Pubs and bars
#
# [51352 rows x 10 columns]

# %% [markdown]
# # Converting two_people_cost into int data type, then diving it by 2 to get cost for 1 person and renaming it to cost for one

# %%
df4['two_people_cost']=df4['two_people_cost'].str.replace(',', '').astype(int)
df4['two_people_cost']=df4['two_people_cost']/2
df4=df4.rename(columns={'two_people_cost':'cost_per_person'})

# %%
df4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rating  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51712         No  3.6 /5     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                                      cuisines  cost_per_person  \
# 0              North Indian, Mughlai, Chinese            400.0
# 1                 Chinese, North Indian, Thai            400.0
# 2                      Cafe, Mexican, Italian            400.0
# 3                  South Indian, North Indian            150.0
# 4                    North Indian, Rajasthani            300.0
# ...                                       ...              ...
# 51712                             Continental            750.0
# 51713                             Finger Food            300.0
# 51714                             Finger Food           1000.0
# 51715                             Finger Food           1250.0
# 51716  Finger Food, North Indian, Continental            750.0
#
#       type_of_restaurant
# 0                 Buffet
# 1                 Buffet
# 2                 Buffet
# 3                 Buffet
# 4                 Buffet
# ...                  ...
# 51712      Pubs and bars
# 51713      Pubs and bars
# 51714      Pubs and bars
# 51715      Pubs and bars
# 51716      Pubs and bars
#
# [51352 rows x 10 columns]

# %% [markdown]
# # Getting info on the remaining null values

# %%
df4.isna().sum()
# Out:
# address                  0
# name                     0
# online_order             0
# book_table               0
# rating                7670
# votes                    0
# location                 0
# cuisines                 0
# cost_per_person          0
# type_of_restaurant       0
# dtype: int64

# %%
df4['rating']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       NaN
# 51714       NaN
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rating, Length: 51352, dtype: object

# %% [markdown]
# # Remove any non-numeric characters and convert to float

# %%
def handlerate(x):
    try:
        return float(x.split('/')[0])
    except:
        return None

# %% [markdown]
# # Applying the function to modify the rating to a float

# %%
df4['rating'] = df4['rating'].apply(handlerate)

# %%
df4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rating  votes                    location  \
# 0            Yes     4.1    775                Banashankari
# 1             No     4.1    787                Banashankari
# 2             No     3.8    918                Banashankari
# 3             No     3.7     88                Banashankari
# 4             No     3.8    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51712         No     3.6     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes     4.3    236  ITPL Main Road, Whitefield
# 51716         No     3.4     13  ITPL Main Road, Whitefield
#
#                                      cuisines  cost_per_person  \
# 0              North Indian, Mughlai, Chinese            400.0
# 1                 Chinese, North Indian, Thai            400.0
# 2                      Cafe, Mexican, Italian            400.0
# 3                  South Indian, North Indian            150.0
# 4                    North Indian, Rajasthani            300.0
# ...                                       ...              ...
# 51712                             Continental            750.0
# 51713                             Finger Food            300.0
# 51714                             Finger Food           1000.0
# 51715                             Finger Food           1250.0
# 51716  Finger Food, North Indian, Continental            750.0
#
#       type_of_restaurant
# 0                 Buffet
# 1                 Buffet
# 2                 Buffet
# 3                 Buffet
# 4                 Buffet
# ...                  ...
# 51712      Pubs and bars
# 51713      Pubs and bars
# 51714      Pubs and bars
# 51715      Pubs and bars
# 51716      Pubs and bars
#
# [51352 rows x 10 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51352 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   address             51352 non-null  object
#  1   name                51352 non-null  object
#  2   online_order        51352 non-null  object
#  3   book_table          51352 non-null  object
#  4   rating              41410 non-null  float64
#  5   votes               51352 non-null  int64
#  6   location            51352 non-null  object
#  7   cuisines            51352 non-null  object
#  8   cost_per_person     51352 non-null  float64
#  9   type_of_restaurant  51352 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 4.3+ MB

# %% [markdown]
# # Filling null values with the mean of ratings.

# %%
df4['rating'] = df4['rating'].fillna(df4['rating'].mean)

# %%
df4.isna().sum()
# Out:
# address               0
# name                  0
# online_order          0
# book_table            0
# rating                0
# votes                 0
# location              0
# cuisines              0
# cost_per_person       0
# type_of_restaurant    0
# dtype: int64

# %% [markdown]
# # Saving cleaned data

# %%
df4.to_csv('zomato_cleaned_data_analysis.csv')
